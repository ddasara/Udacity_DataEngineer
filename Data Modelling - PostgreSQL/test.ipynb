# %%
# %load_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %%
# %sql SELECT * FROM songplay LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(0, '1543449657796', 73, 'paid', None, None, 954, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  (1, '1543449690796', 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"'),
#  (2, '1543449841796', 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"'),
#  (3, '1543449895796', 73, 'paid', None, None, 954, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  (4, '1543450033796', 24, 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')]

# %%
# %sql SELECT * FROM users LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(73, 'Jacob', 'Klein', 'M', 'paid'),
#  (24, 'Layla', 'Griffin', 'F', 'paid'),
#  (24, 'Layla', 'Griffin', 'F', 'paid'),
#  (73, 'Jacob', 'Klein', 'M', 'paid'),
#  (24, 'Layla', 'Griffin', 'F', 'paid')]

# %%
# %sql SELECT * FROM songs LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('SOMJBYD12A6D4F8557', 'Keepin It Real (Skit)', 'ARD0S291187B9B7BF5', '0', 115),
#  ('SOYMRWW12A6D4FAB14', 'The Moon And I (Ordinary Day Album Version)', 'ARKFYS91187B98E58F', '0', 268),
#  ('SOCIWDW12A8C13D406', 'Soul Deep', 'ARMJAGH1187FB546F3', '1969', 148),
#  ('SOIAZJW12AB01853F1', 'Pink World', 'AR8ZCNI1187B9A069B', '1984', 270),
#  ('SOUDSGM12AC9618304', 'Insatiable (Instrumental Version)', 'ARNTLGG11E2835DDB9', '0', 266)]

# %%
# %sql SELECT * FROM artists ;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 72 rows affected.
# [('ARD0S291187B9B7BF5', 'Rated R', 'Ohio', 0, 0),
#  ('ARKFYS91187B98E58F', 'Jeff And Sheri Easter', '', 0, 0),
#  ('ARMJAGH1187FB546F3', 'The Box Tops', 'Memphis, TN', 35, -90),
#  ('AR8ZCNI1187B9A069B', 'Planet P Project', '', 0, 0),
#  ('ARNTLGG11E2835DDB9', 'Clp', '', 0, 0),
#  ('ARGSJW91187B9B1D6B', 'JennyAnyKind', 'North Carolina', 35, -80),
#  ('ARKRRTF1187B9984DA', 'Sonora Santanera', '', 0, 0),
#  ('AR10USD1187B99F3F1', 'Tweeterfriendly Music', 'Burlington, Ontario, Canada', 0, 0),
#  ('AR7G5I41187FB4CE6C', 'Adam Ant', 'London, England', 0, 0),
#  ('ARD7TVE1187B99BFB1', 'Casual', 'California - LA', 0, 0),
#  ('ARXR32B1187FB57099', 'Gob', '', 0, 0),
#  ('ARMJAGH1187FB546F3', 'The Box Tops', 'Memphis, TN', 35, -90),
#  ('ARI3BMM1187FB4255E', 'Alice Stuart', 'Washington', 39, -77),
#  ('AR1ZHYZ1187FB3C717', 'Faiz Ali Faiz', '', 0, 0),
#  ('ARD842G1187B997376', 'Blue Rodeo', 'Toronto, Ontario, Canada', 44, -79),
#  ('ARL7K851187B99ACD2', 'Andy Andy', '', 0, 0),
#  ('ARNPAGP1241B9C7FD4', 'lextrical', '', 0, 0),
#  ('ARIK43K1187B9AE54C', 'Lionel Richie', 'Beverly Hills, CA', 0, 0),
#  ('ARHHO3O1187B989413', 'Bob Azzam', '', 0, 0),
#  ('ARC43071187B990240', 'Wayne Watson', 'Wisner, LA', 0, 0),
#  ('ARQGYP71187FB44566', 'Jimmy Wakely', 'Mineola, AR', 34, -94),
#  ('ARYKCQI1187FB3B18F', 'Tesla', '', 0, 0),
#  ('ARIG6O41187B988BDD', 'Richard Souther', 'United States', 37, -96),
#  ('AREBBGV1187FB523D2', "Mike Jones (Featuring CJ_ Mello & Lil' Bran)", 'Houston, TX', 0, 0),
#  ('ARGUVEV1187B98BA17', 'Sierra Maestra', '', 0, 0),
#  ('ARB29H41187B98F0EF', 'Terry Callier', 'Chicago', 42, -88),
#  ('ARAJPHH1187FB5566A', 'The Shangri-Las', 'Queens, NY', 41, -74),
#  ('ARH4Z031187B9A71F2', 'Faye Adams', 'Newark, NJ', 41, -74),
#  ('AR5KOSW1187FB35FF4', 'Elena', 'Dubai UAE', 50, 15),
#  ('AROUOZZ1187B9ABE51', 'Willie Bobo', 'New York, NY [Spanish Harlem]', 41, -74),
#  ('ARMAC4T1187FB3FA4C', 'The Dillinger Escape Plan', 'Morris Plains, NJ', 41, -74),
#  ('AR47JEX1187B995D81', 'SUE THOMPSON', 'Nevada, MO', 38, -94),
#  ('AR0RCMP1187FB3F427', 'Billie Jo Spears', 'Beaumont, TX', 30, -94),
#  ('AR1Y2PT1187FB5B9CE', 'John Wesley', 'Brandon', 28, -82),
#  ('ARNTLGG11E2835DDB9', 'Clp', '', 0, 0),
#  ('ARGIWFO1187B9B55B7', 'Five Bolt Main', '', 0, 0),
#  ('ARDNS031187B9924F0', 'Tim Wilson', 'Georgia', 33, -83),
#  ('ARI2JSK1187FB496EF', 'Nick Ingman;Gavyn Wright', 'London, England', 52, 0),
#  ('AREDBBQ1187B98AFF5', 'Eddie Calvert', '', 0, 0),
#  ('ARQ9BO41187FB5CF1F', 'John Davis', 'Pennsylvania', 41, -78),
#  ('AROGWRA122988FEE45', 'Christos Dantis', '', 0, 0),
#  ('ARPBNLO1187FB3D52F', 'Tiny Tim', 'New York, NY', 41, -74),
#  ('ARKULSX1187FB45F84', 'Trafik', 'Utah', 39, -112),
#  ('AR9AWNF1187B9AB0B4', 'Kenny G featuring Daryl Hall', 'Seattle, Washington USA', 0, 0),
#  ('AR7ZKHQ1187B98DD73', 'Glad', '', 0, 0),
#  ('ARMBR4Y1187B9990EB', 'David Martin', 'California - SF', 38, -122),
#  ('ARD7TVE1187B99BFB1', 'Casual', 'California - LA', 0, 0),
#  ('AR3JMC51187B9AE49D', 'Backstreet Boys', 'Orlando, FL', 29, -81),
#  ('ARBEBBY1187B9B43DB', 'Tom Petty', 'Gainesville, FL', 0, 0),
#  ('ARAGB2O1187FB3A161', 'Pucho & His Latin Soul Brothers', '', 0, 0),
#  ('ARNNKDK1187B98BBD5', 'Jinx', 'Zagreb Croatia', 46, 16),
#  ('AREDL271187FB40F44', 'Soul Mekanik', '', 0, 0),
#  ('AR36F9J1187FB406F1', 'Bombay Rockers', 'Denmark', 56, 10),
#  ('ARGCY1Y1187B9A4FA5', 'Gloriana', 'Nashville, TN.', 36, -87),
#  ('ARDR4AC1187FB371A1', 'Montserrat Caballé;Placido Domingo;Vicente Sardinero;Judith Blegen;Sherrill Milnes;Georg Solti', '', 0, 0),
#  ('AR62SOJ1187FB47BB5', 'Chase & Status', '', 0, 0),
#  ('ARGSAFR1269FB35070', 'Blingtones', '', 0, 0),
#  ('ARBGXIG122988F409D', 'Steel Rain', 'California - SF', 38, -122),
#  ('ARP6N5A1187B99D1A3', 'Mitch Ryder', 'Hamtramck, MI', 0, 0),
#  ('AR7SMBG1187B9B9066', 'Los Manolos', '', 0, 0),
#  ('ARJIE2Y1187B994AB7', 'Line Renaud', '', 0, 0),
#  ('AR051KA1187B98B2FF', 'Wilks', '', 0, 0),
#  ('ARNF6401187FB57032', 'Sophie B. Hawkins', 'New York, NY [Manhattan]', 41, -74),
#  ('ARPFHN61187FB575F6', 'Lupe Fiasco', 'Chicago, IL', 42, -88),
#  ('ARLTWXK1187FB5A3F8', 'King Curtis', 'Fort Worth, TX', 33, -97),
#  ('AR8IEZO1187B99055E', 'Marc Shaiman', '', 0, 0),
#  ('ARWB3G61187FB49404', 'Steve Morse', 'Hamilton, Ohio', 0, 0),
#  ('AREVWGE1187B9B890A', 'Bitter End', 'Noci (BA)', -13, -42),
#  ('AR0IAWL1187B9A96D0', 'Danilo Perez', 'Panama', 8, -80),
#  ('ARVBRGZ1187FB4675A', 'Gwen Stefani', '', 0, 0),
#  ('AR558FS1187FB45658', '40 Grit', '', 0, 0),
#  ('ARULZCI1241B9C8611', 'Luna Orbit Project', '', 0, 0)]

# %%
# %sql SELECT * FROM time LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('2018-11-29 00:00:57.796', 0, '29', '11', '2018', '3', '48'),
#  ('2018-11-29 00:01:30.796', 0, '29', '11', '2018', '3', '48'),
#  ('2018-11-29 00:04:01.796', 0, '29', '11', '2018', '3', '48'),
#  ('2018-11-29 00:04:55.796', 0, '29', '11', '2018', '3', '48'),
#  ('2018-11-29 00:07:13.796', 0, '29', '11', '2018', '3', '48')]

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).
